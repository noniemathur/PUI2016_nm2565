# %%
# !for ((y=0; y<=9; y+=1)); do wget ftp://ftp.census.gov/econ200$y\/CBP_CSV/zbp0$y\totals.zip; done
# Out:
# --2016-11-29 15:33:45--  ftp://ftp.census.gov/econ2000/CBP_CSV/zbp00totals.zip
#            => “zbp00totals.zip”
# Resolving ftp.census.gov... 148.129.75.35, 2610:20:2010:a09:1000:0:9481:4b23
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Logging in as anonymous ...
# Error in server response, closing control connection.
# Retrying.
#
# --2016-11-29 15:38:47--  ftp://ftp.census.gov/econ2000/CBP_CSV/zbp00totals.zip
#   (try: 2) => “zbp00totals.zip”
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /econ2000/CBP_CSV ...
# No such directory “econ2000/CBP_CSV”.
#
# --2016-11-29 15:38:47--  ftp://ftp.census.gov/econ2001/CBP_CSV/zbp01totals.zip
#            => “zbp01totals.zip”
# Resolving ftp.census.gov... 148.129.75.35, 2610:20:2010:a09:1000:0:9481:4b23
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /econ2001/CBP_CSV ...
# No such directory “econ2001/CBP_CSV”.
#
# --2016-11-29 15:38:47--  ftp://ftp.census.gov/econ2002/CBP_CSV/zbp02totals.zip
#            => “zbp02totals.zip.1”
# Resolving ftp.census.gov... 148.129.75.35, 2610:20:2010:a09:1000:0:9481:4b23
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /econ2002/CBP_CSV ... done.
# ==> SIZE zbp02totals.zip ... 620754
# ==> PASV ... done.    ==> RETR zbp02totals.zip ... done.
# Length: 620754 (606K) (unauthoritative)
#
# 100%[======================================>] 620,754      544K/s   in 1.1s
#
# 2016-11-29 15:38:48 (544 KB/s) - “zbp02totals.zip.1” saved [620754]
#
# --2016-11-29 15:38:48--  ftp://ftp.census.gov/econ2003/CBP_CSV/zbp03totals.zip
#            => “zbp03totals.zip.1”
# Resolving ftp.census.gov... 148.129.75.35, 2610:20:2010:a09:1000:0:9481:4b23
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Logging in as anonymous ...
# Error in server response, closing control connection.
# Retrying.
#
# --2016-11-29 15:43:49--  ftp://ftp.census.gov/econ2003/CBP_CSV/zbp03totals.zip
#   (try: 2) => “zbp03totals.zip.1”
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /econ2003/CBP_CSV ... done.
# ==> SIZE zbp03totals.zip ... 622790
# ==> PASV ... done.    ==> RETR zbp03totals.zip ... done.
# Length: 622790 (608K) (unauthoritative)
#
# 100%[======================================>] 622,790     --.-K/s   in 1.1s
#
# 2016-11-29 15:43:50 (553 KB/s) - “zbp03totals.zip.1” saved [622790]
#
# --2016-11-29 15:43:50--  ftp://ftp.census.gov/econ2004/CBP_CSV/zbp04totals.zip
#            => “zbp04totals.zip.1”
# Resolving ftp.census.gov... 148.129.75.35, 2610:20:2010:a09:1000:0:9481:4b23
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /econ2004/CBP_CSV ... done.
# ==> SIZE zbp04totals.zip ... 625803
# ==> PASV ... done.    ==> RETR zbp04totals.zip ... done.
# Length: 625803 (611K) (unauthoritative)
#
# 100%[======================================>] 625,803      551K/s   in 1.1s
#
# 2016-11-29 15:43:52 (551 KB/s) - “zbp04totals.zip.1” saved [625803]
#
# --2016-11-29 15:43:52--  ftp://ftp.census.gov/econ2005/CBP_CSV/zbp05totals.zip
#            => “zbp05totals.zip.1”
# Resolving ftp.census.gov... 148.129.75.35, 2610:20:2010:a09:1000:0:9481:4b23
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /econ2005/CBP_CSV ... done.
# ==> SIZE zbp05totals.zip ... 627583
# ==> PASV ... done.    ==> RETR zbp05totals.zip ... done.
# Length: 627583 (613K) (unauthoritative)
#
# 100%[======================================>] 627,583      546K/s   in 1.1s
#
# 2016-11-29 15:43:53 (546 KB/s) - “zbp05totals.zip.1” saved [627583]
#
# --2016-11-29 15:43:53--  ftp://ftp.census.gov/econ2006/CBP_CSV/zbp06totals.zip
#            => “zbp06totals.zip.1”
# Resolving ftp.census.gov... 148.129.75.35, 2610:20:2010:a09:1000:0:9481:4b23
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Logging in as anonymous ...
# Error in server response, closing control connection.
# Retrying.
#
# --2016-11-29 15:48:56--  ftp://ftp.census.gov/econ2006/CBP_CSV/zbp06totals.zip
#   (try: 2) => “zbp06totals.zip.1”
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /econ2006/CBP_CSV ... done.
# ==> SIZE zbp06totals.zip ... 629107
# ==> PASV ... done.    ==> RETR zbp06totals.zip ... done.
# Length: 629107 (614K) (unauthoritative)
#
# 100%[======================================>] 629,107     --.-K/s   in 1.1s
#
# 2016-11-29 15:48:57 (573 KB/s) - “zbp06totals.zip.1” saved [629107]
#
# --2016-11-29 15:48:57--  ftp://ftp.census.gov/econ2007/CBP_CSV/zbp07totals.zip
#            => “zbp07totals.zip.1”
# Resolving ftp.census.gov... 148.129.75.35, 2610:20:2010:a09:1000:0:9481:4b23
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Logging in as anonymous ...
# Error in server response, closing control connection.
# Retrying.
#
# --2016-11-29 15:54:01--  ftp://ftp.census.gov/econ2007/CBP_CSV/zbp07totals.zip
#   (try: 2) => “zbp07totals.zip.1”
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Logging in as anonymous ...
# Error in server greeting.
# Retrying.
#
# --2016-11-29 15:55:40--  ftp://ftp.census.gov/econ2007/CBP_CSV/zbp07totals.zip
#   (try: 3) => “zbp07totals.zip.1”
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Logging in as anonymous ...
# Error in server response, closing control connection.
# Retrying.
#
# --2016-11-29 16:00:43--  ftp://ftp.census.gov/econ2007/CBP_CSV/zbp07totals.zip
#   (try: 4) => “zbp07totals.zip.1”
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Logging in as anonymous ...
# Error in server response, closing control connection.
# Retrying.
#
# --2016-11-29 16:05:48--  ftp://ftp.census.gov/econ2007/CBP_CSV/zbp07totals.zip
#   (try: 5) => “zbp07totals.zip.1”
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Logging in as anonymous ...
# Error in server response, closing control connection.
# Retrying.
#
# --2016-11-29 16:10:58--  ftp://ftp.census.gov/econ2007/CBP_CSV/zbp07totals.zip
#   (try: 6) => “zbp07totals.zip.1”
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /econ2007/CBP_CSV ... done.
# ==> SIZE zbp07totals.zip ... 667754
# ==> PASV ... done.    ==> RETR zbp07totals.zip ... done.
# Length: 667754 (652K) (unauthoritative)
#
# 100%[======================================>] 667,754      510K/s   in 1.3s
#
# 2016-11-29 16:11:00 (510 KB/s) - “zbp07totals.zip.1” saved [667754]
#
# --2016-11-29 16:11:00--  ftp://ftp.census.gov/econ2008/CBP_CSV/zbp08totals.zip
#            => “zbp08totals.zip”
# Resolving ftp.census.gov... 148.129.75.35, 2610:20:2010:a09:1000:0:9481:4b23
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Logging in as anonymous ...
# Error in server response, closing control connection.
# Retrying.
#
# --2016-11-29 16:16:03--  ftp://ftp.census.gov/econ2008/CBP_CSV/zbp08totals.zip
#   (try: 2) => “zbp08totals.zip”
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Logging in as anonymous ...
# Error in server response, closing control connection.
# Retrying.
#
# --2016-11-29 16:21:05--  ftp://ftp.census.gov/econ2008/CBP_CSV/zbp08totals.zip
#   (try: 3) => “zbp08totals.zip”
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /econ2008/CBP_CSV ... done.
# ==> SIZE zbp08totals.zip ... 663242
# ==> PASV ... done.    ==> RETR zbp08totals.zip ... done.
# Length: 663242 (648K) (unauthoritative)
#
# 100%[======================================>] 663,242      506K/s   in 1.3s
#
# 2016-11-29 16:21:07 (506 KB/s) - “zbp08totals.zip” saved [663242]
#
# --2016-11-29 16:21:07--  ftp://ftp.census.gov/econ2009/CBP_CSV/zbp09totals.zip
#            => “zbp09totals.zip”
# Resolving ftp.census.gov... 148.129.75.35, 2610:20:2010:a09:1000:0:9481:4b23
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /econ2009/CBP_CSV ... done.
# ==> SIZE zbp09totals.zip ... 660109
# ==> PASV ... done.    ==> RETR zbp09totals.zip ... done.
# Length: 660109 (645K) (unauthoritative)
#
# 100%[======================================>] 660,109      504K/s   in 1.3s
#
# 2016-11-29 16:21:08 (504 KB/s) - “zbp09totals.zip” saved [660109]

# %%
import zipfile
import numpy as np
import pandas as pd
import geopandas as gp
import matplotlib as plt
import matplotlib.cm as cm

from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist, pdist
from sklearn.metrics import silhouette_samples, silhouette_score
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
zc_shape = gp.read_file('nyc-zip-code-tabulation-areas-polygons.geojson')
zc_shape.head()
# Out:
#                                                  @id  BLDGpostalCode CTY_FIPS  \
# 0  http://nyc.pediacities.com/Resource/PostalCode...               0      081
# 1  http://nyc.pediacities.com/Resource/PostalCode...               0      081
# 2  http://nyc.pediacities.com/Resource/PostalCode...               0      081
# 3  http://nyc.pediacities.com/Resource/PostalCode...               0      081
# 4  http://nyc.pediacities.com/Resource/PostalCode...               0      081
#
#    OBJECTID          PO_NAME STATE ST_FIPS    Shape_Area    Shape_Leng  \
# 0         1  Jackson Heights    NY      36  2.016328e+07  20624.692317
# 1         2        Glen Oaks    NY      36  2.260653e+07  23002.816039
# 2         3    New Hyde Park    NY      36  6.269333e+06  15749.161511
# 3         4        Bellerose    NY      36  4.941836e+07  35932.810639
# 4         5    Fresh Meadows    NY      36  6.938587e+07  38693.565676
#
#   borough                                           geometry postalCode
# 0  Queens  POLYGON ((-73.86942457284175 40.74915687096787...      11372
# 1  Queens  POLYGON ((-73.71068374074007 40.75004039450917...      11004
# 2  Queens  POLYGON ((-73.70098278625547 40.73889569923034...      11040
# 3  Queens  POLYGON ((-73.72270447144122 40.75373371438336...      11426
# 4  Queens  POLYGON ((-73.81088634744755 40.72717187575918...      11365

# %%
zc_shape.columns
# Out:
# Index([           u'@id', u'BLDGpostalCode',       u'CTY_FIPS',
#              u'OBJECTID',        u'PO_NAME',          u'STATE',
#               u'ST_FIPS',     u'Shape_Area',     u'Shape_Leng',
#               u'borough',       u'geometry',     u'postalCode'],
#       dtype='object')

# %%
zc_shape = zc_shape.drop(['@id','BLDGpostalCode','CTY_FIPS','ST_FIPS',
                                    'OBJECTID','Shape_Area','Shape_Leng']
                                   , axis = 1)
zc_shape = zc_shape.rename(columns={'postalCode' : 'zip'})
zc_shape.head()
# Out:
#            PO_NAME STATE borough  \
# 0  Jackson Heights    NY  Queens
# 1        Glen Oaks    NY  Queens
# 2    New Hyde Park    NY  Queens
# 3        Bellerose    NY  Queens
# 4    Fresh Meadows    NY  Queens
#
#                                             geometry    zip
# 0  POLYGON ((-73.86942457284175 40.74915687096787...  11372
# 1  POLYGON ((-73.71068374074007 40.75004039450917...  11004
# 2  POLYGON ((-73.70098278625547 40.73889569923034...  11040
# 3  POLYGON ((-73.72270447144122 40.75373371438336...  11426
# 4  POLYGON ((-73.81088634744755 40.72717187575918...  11365

# %%
zc_shape['zip'] = pd.to_numeric(zc_shape['zip'])
zc_shape['zip']
# Out:
# 0      11372
# 1      11004
# 2      11040
# 3      11426
# 4      11365
# 5      11373
# 6      11001
# 7      11375
# 8      11427
# 9      11374
# 10     11366
# 11     11423
# 12     11428
# 13     11432
# 14     11379
# 15     11429
# 16     11435
# 17     11415
# 18     11418
# 19     11433
# 20     11451
# 21     11221
# 22     11421
# 23     11419
# 24     11434
# 25     11216
# 26     11416
# 27     11233
# 28     11436
# 29     11213
#        ...
# 232    10106
# 233    10158
# 234    10041
# 235    10120
# 236    10278
# 237    10155
# 238    10022
# 239    10043
# 240    10081
# 241    10096
# 242    10097
# 243    10196
# 244    10196
# 245    10275
# 246    10265
# 247    10045
# 248    10047
# 249    10047
# 250    10080
# 251    10203
# 252    10259
# 253    10260
# 254    10285
# 255    10286
# 256    11370
# 257    10065
# 258    10075
# 259    10069
# 260    10281
# 261    10282
# Name: zip, dtype: int64

# %%
year = []
for i in range(94, 100, 1):
    year.append(str(i))
for i in range(0, 10, 1):
    year.append('0'+str(i))
for i in range(10, 15, 1):
    year.append(str(i))

# %% [markdown]
# Reading the datafiles

# %%
for i in year:
    zf = zipfile.ZipFile('zbp'+ i +'totals.zip')
    business_data = pd.read_csv(zf.open('zbp'+i+'totals.zip'.replace('.zip','.txt')))
    print("Year "+str(i)+'\n')
    print(business_data.head())
    print('\n')
# Out:
# Year 94
#
#     zip         name empflag   emp    qp1      ap  est
# 0  1001   Agawam, MA     NaN  6198  33601  155158  439
# 1  1002  Amherst, MA     NaN  6073  28924  127367  450
# 2  1003  Amherst, MA     NaN    68    367    1604   10
# 3  1004  Amherst, MA     NaN   210    844    4302   47
# 4  1005    Barre, MA     NaN   678   3010   13521   92
#
#
# Year 95
#
#     zip             name empflag   emp    qp1      ap  est
# 0   501   Holtsville, NY       B     0      0       0    2
# 1  1000  Springfield, MA     NaN    49    529    2127    4
# 2  1001       Agawam, MA     NaN  5920  32993  152512  439
# 3  1002      Amherst, MA     NaN  6153  31645  132699  467
# 4  1003      Amherst, MA     NaN    89    380    1698   10
#
#
# Year 96
#
#     zip             name empflag   emp    qp1      ap  est
# 0   501   Holtsville, NY       B     0      0       0    4
# 1  1000  Springfield, MA     NaN   161   1494    6671   11
# 2  1001       Agawam, MA     NaN  6130  37746  171045  433
# 3  1002      Amherst, MA     NaN  6441  32964  141756  487
# 4  1003      Amherst, MA     NaN    77    364    1686   13
#
#
# Year 97
#
#     zip             name empflag   emp    qp1      ap  est
# 0   501   HOLTSVILLE, NY     NaN    47    168     523    4
# 1  1000  SPRINGFIELD, MA       E     0      0       0    8
# 2  1001       AGAWAM, MA     NaN  6900  44201  196588  457
# 3  1002      AMHERST, MA     NaN  6328  37558  154955  500
# 4  1003      AMHERST, MA     NaN    90    448    2122   15
#
#
# Year 98
#
#     ZIP            NAME EMPFLAG   EMP    QP1      AP  EST
# 0   501  HOLTSVILLE, NY     NaN     2     11      57    3
# 1  1001      AGAWAM, MA     NaN  7121  47926  215641  444
# 2  1002     AMHERST, MA     NaN  6278  34435  154135  490
# 3  1003     AMHERST, MA     NaN    86    535    2301   14
# 4  1004     AMHERST, MA     NaN   172    811    4043   31
#
#
# Year 99
#
#     ZIP            NAME EMPFLAG   EMP    QP1      AP  EST
# 0   501  HOLTSVILLE, NY       B     0      0       0    2
# 1  1001      AGAWAM, MA     NaN  7786  58129  252624  469
# 2  1002     AMHERST, MA     NaN  6607  36220  163105  558
# 3  1003     AMHERST, MA     NaN    82    336    1646   13
# 4  1004     AMHERST, MA     NaN   600   2659   10426   35
#
#
# Year 00
#
#     ZIP            NAME EMPFLAG   EMP    QP1      AP  EST
# 0   501  HOLTSVILLE, NY       A     0      0       0    1
# 1  1001      AGAWAM, MA     NaN  8042  59833  259661  493
# 2  1002     AMHERST, MA     NaN  6547  36719  169658  563
# 3  1003     AMHERST, MA     NaN    82    308    2482   13
# 4  1004     AMHERST, MA     NaN   717   2049    5826   48
#
#
# Year 01
#
#     ZIP            NAME EMPFLAG   EMP    QP1      AP  EST
# 0   501  HOLTSVILLE, NY       B     0      0       0    6
# 1  1001      AGAWAM, MA     NaN  8522  64404  270625  490
# 2  1002     AMHERST, MA     NaN  6955  42682  182632  587
# 3  1003     AMHERST, MA     NaN   175    629    2811   13
# 4  1004     AMHERST, MA     NaN   224   1104    4723   37
#
#
# Year 02
#
#     ZIP            NAME EMPFLAG   EMP    QP1      AP  EST
# 0   501  HOLTSVILLE, NY     NaN    40    148     660   11
# 1  1001      AGAWAM, MA       I     0      0       0  490
# 2  1002     AMHERST, MA     NaN  6866  39616  170725  566
# 3  1003     AMHERST, MA     NaN   268   1097    3900   15
# 4  1004     AMHERST, MA     NaN   169   1015    4032   23
#
#
# Year 03
#
#     zip            name empflag   emp    qp1      ap  est
# 0   501  HOLTSVILLE, NY       B     0      0       0    7
# 1  1001      AGAWAM, MA     NaN  8448  61611  271048  505
# 2  1002     AMHERST, MA     NaN  6771  40259  171869  586
# 3  1003     AMHERST, MA     NaN   258   1142    4745   16
# 4  1004     AMHERST, MA     NaN   146    972    4003   21
#
#
# Year 04
#
#     zip            name empflag   emp    qp1      ap  est
# 0   501  HOLTSVILLE, NY     NaN    34    170     773    8
# 1  1001      AGAWAM, MA     NaN  8650  61626  279815  500
# 2  1002     AMHERST, MA     NaN  6827  41882  180175  584
# 3  1003     AMHERST, MA     NaN   283    971    4196   15
# 4  1004     AMHERST, MA     NaN   178   1122    4311   43
#
#
# Year 05
#
#     zip            name empflag    emp    qp1      ap  est
# 0   501  HOLTSVILLE, NY       B      0      0       0    2
# 1  1001      AGAWAM, MA       I      0      0       0  509
# 2  1002     AMHERST, MA     NaN   6691  43876  192996  589
# 3  1003     AMHERST, MA     NaN    115    582    2631   12
# 4  1004     AMHERST, MA     NaN  10356   7958   46893   31
#
#
# Year 06
#
#     zip            name empflag   emp    qp1      ap  est
# 0   501  HOLTSVILLE, NY     NaN    39    216     979    8
# 1  1001      AGAWAM, MA     NaN  9564  73282  328021  509
# 2  1002     AMHERST, MA     NaN  6977  49260  211677  582
# 3  1003     AMHERST, MA     NaN   123    698    3156   12
# 4  1004     AMHERST, MA     NaN   276   1464    5038   30
#
#
# Year 07
#
#     zip            name empflag emp_nf    emp qp1_nf    qp1 ap_nf      ap  est
# 0   501  HOLTSVILLE, NY       B      D      0      D      0     D       0    5
# 1  1001      AGAWAM, MA     NaN      G   9663      G  78154     G  333829  503
# 2  1002     AMHERST, MA     NaN      G  12635      G  73904     G  311951  596
# 3  1003     AMHERST, MA     NaN      H    141      H   1063     H    4377   16
# 4  1004     AMHERST, MA       C      S      0      H   1254     H    5141   20
#
#
# Year 08
#
#     zip            name empflag emp_nf    emp qp1_nf    qp1 ap_nf      ap  est
# 0   501  HOLTSVILLE, NY       B      D      0      D      0     D       0    3
# 1  1001      AGAWAM, MA     NaN      G   9681      G  76511     G  340969  477
# 2  1002     AMHERST, MA     NaN      G  13152      G  79481     G  330150  584
# 3  1003     AMHERST, MA     NaN      G    154      H   1076     G    4734   17
# 4  1004     AMHERST, MA     NaN      H    187      S      0     H    6027   18
#
#
# Year 09
#
#     zip            name empflag emp_nf    emp qp1_nf    qp1 ap_nf      ap  est
# 0   501  HOLTSVILLE, NY       A      D      0      D      0     D       0    2
# 1  1001      AGAWAM, MA     NaN      G   9950      G  72700     G  318373  458
# 2  1002     AMHERST, MA     NaN      G  13729      G  86730     G  350310  571
# 3  1003     AMHERST, MA     NaN      G    212      H   1656     H    5684   16
# 4  1004     AMHERST, MA     NaN      H    182      H   1436     H    6412   18
#
#
# Year 10
#
#     zip            name empflag emp_nf    emp qp1_nf    qp1 ap_nf      ap  \
# 0   501  HOLTSVILLE, NY       A      D      0      D      0     D       0
# 1  1001      AGAWAM, MA     NaN      G   9185      G  70693     G  314508
# 2  1002     AMHERST, MA     NaN      G  15633      G  82069     G  351589
# 3  1003     AMHERST, MA     NaN      G    168      H   1297     H    5761
# 4  1004     AMHERST, MA     NaN      H    189      H   1710     H    7241
#
#    est        city stabbr   cty_name
# 0    2  HOLTSVILLE     NY    SUFFOLK
# 1  448      AGAWAM     MA    HAMPDEN
# 2  570     AMHERST     MA  HAMPSHIRE
# 3   16     AMHERST     MA  HAMPSHIRE
# 4   21     AMHERST     MA  HAMPSHIRE
#
#
# Year 11
#
#     zip            name empflag emp_nf    emp qp1_nf    qp1 ap_nf      ap  \
# 0   501  HOLTSVILLE, NY       A      D      0      D      0     D       0
# 1  1001      AGAWAM, MA     NaN      G   8788      G  75093     G  322008
# 2  1002     AMHERST, MA     NaN      G  15878      G  84225     G  360685
# 3  1003     AMHERST, MA     NaN      G    198      H   2054     H    8591
# 4  1004     AMHERST, MA       C      S      0      H   1578     H    7063
#
#    est        city stabbr   cty_name
# 0    2  HOLTSVILLE     NY    SUFFOLK
# 1  436      AGAWAM     MA    HAMPDEN
# 2  558     AMHERST     MA  HAMPSHIRE
# 3   16     AMHERST     MA  HAMPSHIRE
# 4   19     AMHERST     MA  HAMPSHIRE
#
#
# Year 12
#
#     zip            name empflag emp_nf    emp qp1_nf    qp1 ap_nf      ap  \
# 0   501  HOLTSVILLE, NY       A      D      0      D      0     D       0
# 1  1001      AGAWAM, MA     NaN      G   9033      G  84256     G  356861
# 2  1002     AMHERST, MA     NaN      H  16422      G  90914     G  378362
# 3  1003     AMHERST, MA     NaN      G    199      G   2003     G    8009
# 4  1004     AMHERST, MA     NaN      H    161      H   1140     H    5107
#
#    est        city stabbr   cty_name
# 0    2  HOLTSVILLE     NY    SUFFOLK
# 1  453      AGAWAM     MA    HAMPDEN
# 2  572     AMHERST     MA  HAMPSHIRE
# 3   15     AMHERST     MA  HAMPSHIRE
# 4   16     AMHERST     MA  HAMPSHIRE
#
#
# Year 13
#
#     zip            name empflag emp_nf    emp qp1_nf    qp1 ap_nf      ap  \
# 0   501  HOLTSVILLE, NY       A      D      0      D      0     D       0
# 1  1001      AGAWAM, MA     NaN      G   9418      G  92083     G  373116
# 2  1002     AMHERST, MA     NaN      H  17263      G  95047     G  398992
# 3  1003     AMHERST, MA     NaN      G    184      H   1754     H    7181
# 4  1004     AMHERST, MA     NaN      H    179      H   1168     H    5019
#
#    est        city stabbr   cty_name
# 0    2  HOLTSVILLE     NY    SUFFOLK
# 1  439      AGAWAM     MA    HAMPDEN
# 2  572     AMHERST     MA  HAMPSHIRE
# 3   15     AMHERST     MA  HAMPSHIRE
# 4   16     AMHERST     MA  HAMPSHIRE
#
#
# Year 14
#
#     zip            name empflag emp_nf    emp qp1_nf    qp1 ap_nf      ap  \
# 0   501  HOLTSVILLE, NY       B      D      0      D      0     D       0
# 1  1001      AGAWAM, MA     NaN      G   9110      G  88574     G  364418
# 2  1002     AMHERST, MA     NaN      H  17513      G  99432     G  421772
# 3  1003     AMHERST, MA     NaN      G    227      H   1911     H    8026
# 4  1004     AMHERST, MA       C      S      0      S      0     H    4921
#
#    est        city stabbr   cty_name
# 0    4  HOLTSVILLE     NY    SUFFOLK
# 1  458      AGAWAM     MA    HAMPDEN
# 2  560     AMHERST     MA  HAMPSHIRE
# 3   18     AMHERST     MA  HAMPSHIRE
# 4   13     AMHERST     MA  HAMPSHIRE

# %%
for i in year:
    zf = zipfile.ZipFile('zbp'+i+'totals.zip')
    temp = pd.read_csv(zf.open('zbp'+i+'totals.zip'.replace('.zip','.txt')))
    temp.columns = map(str.lower, temp.columns)
    temp = temp[['zip', 'est']]
    temp.rename(columns={'est' : 'est'+str(i)}, inplace=True)
    zc_shape = zc_shape.merge(temp, on = 'zip', how = 'inner')

# %%
zipcode_shape.shape
# Out:
# (262, 12)

# %% [markdown]
# The data is 2 dimensional

# %%
zc_shape.columns
# Out:
# Index([ u'PO_NAME',    u'STATE',  u'borough', u'geometry',      u'zip',
#           u'est94',    u'est95',    u'est96',    u'est97',    u'est98',
#           u'est99',    u'est00',    u'est01',    u'est02',    u'est03',
#           u'est04',    u'est05',    u'est06',    u'est07',    u'est08',
#           u'est09',    u'est10',    u'est11',    u'est12',    u'est13',
#           u'est14'],
#       dtype='object')

# %%
zc_shape.head()
# Out:
#            PO_NAME STATE borough  \
# 0  Jackson Heights    NY  Queens
# 1        Glen Oaks    NY  Queens
# 2    New Hyde Park    NY  Queens
# 3        Bellerose    NY  Queens
# 4    Fresh Meadows    NY  Queens
#
#                                             geometry    zip  est94  est95  \
# 0  POLYGON ((-73.86942457284175 40.74915687096787...  11372   1229   1236
# 1  POLYGON ((-73.71068374074007 40.75004039450917...  11004    194    188
# 2  POLYGON ((-73.70098278625547 40.73889569923034...  11040   1422   1414
# 3  POLYGON ((-73.72270447144122 40.75373371438336...  11426    326    219
# 4  POLYGON ((-73.81088634744755 40.72717187575918...  11365    492    476
#
#    est96  est97  est98  ...    est05  est06  est07  est08  est09  est10  \
# 0   1292   1309   1351  ...     1539   1527   1545   1538   1572   1629
# 1    176    192    194  ...      225    226    238    227    233    229
# 2   1335   1344   1344  ...     1441   1454   1488   1503   1475   1494
# 3    209    198    203  ...      226    226    228    226    237    248
# 4    483    522    509  ...      604    608    617    616    628    643
#
#    est11  est12  est13  est14
# 0   1647   1724   1759   1768
# 1    222    241    241    250
# 2   1488   1510   1539   1534
# 3    256    266    258    260
# 4    677    679    714    731
#
# [5 rows x 26 columns]

# %% [markdown]
# Whitening the data

# %%
est_mean = zc_shape.iloc[:,range(5,26)].mean(axis = 1)
est_std = zc_shape.iloc[:,range(5,26)].std(axis = 1)
zc_shape.iloc[:,range(5,26)] = zc_shape.iloc[:,range(4,26)].apply(lambda x: (x- est_mean) / est_std)
zc_shape.head()
# Out:
#            PO_NAME STATE borough  \
# 0  Jackson Heights    NY  Queens
# 1        Glen Oaks    NY  Queens
# 2    New Hyde Park    NY  Queens
# 3        Bellerose    NY  Queens
# 4    Fresh Meadows    NY  Queens
#
#                                             geometry    zip     est94  \
# 0  POLYGON ((-73.86942457284175 40.74915687096787...  11372 -1.650515
# 1  POLYGON ((-73.71068374074007 40.75004039450917...  11004 -0.974535
# 2  POLYGON ((-73.70098278625547 40.73889569923034...  11040 -0.118051
# 3  POLYGON ((-73.72270447144122 40.75373371438336...  11426  3.212291
# 4  POLYGON ((-73.81088634744755 40.72717187575918...  11365 -1.332578
#
#       est95     est96     est97     est98    ...        est05     est06  \
# 0 -1.607088 -1.259673 -1.154208 -0.893647    ...     0.272673  0.198227
# 1 -1.248013 -1.794968 -1.065695 -0.974535    ...     0.438432  0.484012
# 2 -0.234030 -1.379327 -1.248850 -1.248850    ...     0.157401  0.345867
# 3 -0.444253 -0.785986 -1.161892 -0.991026    ...    -0.205040 -0.205040
# 4 -1.549090 -1.454366 -0.926619 -1.102534    ...     0.183004  0.237132
#
#       est07     est08     est09     est10     est11     est12     est13  \
# 0  0.309896  0.266469  0.477400  0.831018  0.942687  1.420382  1.637516
# 1  1.030967  0.529592  0.803069  0.620751  0.301694  1.167706  1.167706
# 2  0.838780  1.056241  0.650313  0.925765  0.838780  1.157723  1.578149
# 3 -0.136693 -0.205040  0.170867  0.546773  0.820159  1.161892  0.888506
# 4  0.358920  0.345388  0.507772  0.710751  1.170839  1.197903  1.671522
#
#       est14
# 0  1.693350
# 1  1.577923
# 2  1.505662
# 3  0.956853
# 4  1.901566
#
# [5 rows x 26 columns]

# %%
zc_shape.columns
# Out:
# Index([ u'PO_NAME',    u'STATE',  u'borough', u'geometry',      u'zip',
#           u'est94',    u'est95',    u'est96',    u'est97',    u'est98',
#           u'est99',    u'est00',    u'est01',    u'est02',    u'est03',
#           u'est04',    u'est05',    u'est06',    u'est07',    u'est08',
#           u'est09',    u'est10',    u'est11',    u'est12',    u'est13',
#           u'est14'],
#       dtype='object')

# %%
def elbow(data,K):
#data is your input as numpy form
#K is a list of number of clusters you would like to show.
    # Run the KMeans model and save all the results for each number of clusters
    KM = [KMeans(n_clusters=k).fit(data) for k in K]
    
    # Save the centroids for each model with a increasing k
    centroids = [k.cluster_centers_ for k in KM]

    # For each k, get the distance between the data with each center. 
    D_k = [cdist(data, cent, 'euclidean') for cent in centroids]
    
    # But we only need the distance to the nearest centroid since we only calculate dist(x,ci) for its own cluster.
    globals()['dist'] = [np.min(D,axis=1) for D in D_k]
    
    # Calculate the Average SSE.
    avgWithinSS = [sum(d)/data.shape[0] for d in dist]
    
    
    # elbow curve
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.plot(K, avgWithinSS, 'b*-')
    plt.grid(True)
    plt.xlabel('Number of clusters')
    plt.ylabel('Average within-cluster sum of squares')
    plt.title('Elbow for KMeans clustering')
    plt.show()
    
    
    # Total with-in sum of square plot. Another way to show the result.
    wcss = [sum(d**2) for d in dist]
    tss = sum(pdist(data)**2)/data.shape[0]
    bss = tss-wcss
    
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.plot(K, bss/tss*100, 'b*-')
    plt.grid(True)
    plt.xlabel('Number of clusters')
    plt.ylabel('Percentage of variance explained')
    plt.title('Elbow for KMeans clustering')
    plt.show()

# %%
elbow(zc_shape.iloc[:, range(5,26)], range(1,30))

# %%
X=zc_shape.iloc[:, range(5,26)]
range_n_clusters = range(2,10)
for n_clusters in range_n_clusters:
    km = KMeans(n_clusters=n_clusters, random_state=324)
    cluster_labels = km.fit_predict(X)
    silhouette_avg = silhouette_score(X, cluster_labels)
    print("For n_clusters ={},".format(n_clusters)+" the average silhouette_score is :{}".format(silhouette_avg))
# Out:
# For n_clusters =2, the average silhouette_score is :0.572142801777
# For n_clusters =3, the average silhouette_score is :0.541435020202
# For n_clusters =4, the average silhouette_score is :0.495601550463
# For n_clusters =5, the average silhouette_score is :0.478801351965
# For n_clusters =6, the average silhouette_score is :0.234252779225
# For n_clusters =7, the average silhouette_score is :0.269653212641
# For n_clusters =8, the average silhouette_score is :0.1408578891
# For n_clusters =9, the average silhouette_score is :0.20686549319

# %%
mod_km_2 = KMeans(n_clusters=2, init='k-means++', n_init=10, max_iter=300, tol=0.0001, 
                verbose=0, random_state=None).fit(X)

# %%
centers_2 = mod_km_2.cluster_centers_

# %%
plt.figure(figsize=(8,8))
plt.scatter(zc_shape[mod_km_2.labels_ == 0].iloc[:,5], zc_shape[mod_km_2.labels_ == 0].iloc[:,24], \
           color='lightblue', alpha=0.3, label="Cluster 1")
plt.scatter(centers_2[0][0], centers_2[0][-1], marker='*', s=100, color='blue', label="Cluster 1 Center")

plt.scatter(zc_shape[mod_km_2.labels_ == 1].iloc[:,5], zc_shape[mod_km_2.labels_ == 1].iloc[:,24], \
           color='red', alpha=0.3, label="Cluster 2")
plt.scatter(centers_2[1][0], centers_2[1][-1], marker='*', s=100, color='red', label="Cluster 2 Center")

plt.xlabel("EST94")
plt.ylabel("EST14")
plt.title("KMeans Cluster: The Number Of ESTABLISHMENTS")
plt.legend(fontsize=10, loc='best')

# %%
#KMeans cluster
kmeans_cluster = KMeans(2).fit(zc_shape.iloc[:, range(5,26)])
centers = kmeans_cluster.cluster_centers_
zc_shape['km_labels'] = kmeans_cluster.labels_

# %%
#Plotting KMeans cluster spatially
f, ax = plt.subplots(figsize=(10,10))
zc_shape.plot(cmap='jet', column='km_labels', ax=ax, categorical=True, k=2)
ax.set_title("KMeans, k=2", fontsize=25)
ax.axes.get_xaxis().set_visible(False)
ax.axes.get_yaxis().set_visible(False)

# %%
mod_km_3 = KMeans(n_clusters=3, init='k-means++', n_init=10, max_iter=300, tol=0.0001, 
                verbose=0, random_state=None).fit(X)

# %%
centers_3 = mod_km_3.cluster_centers_

# %%
plt.figure(figsize=(8,8))
plt.scatter(zc_shape[mod_km_3.labels_ == 0].iloc[:,5], zc_shape[mod_km_3.labels_ == 0].iloc[:,24], \
           color='lightblue', alpha=0.3, label="Cluster 1")
plt.scatter(centers_3[0][0], centers_3[0][-1], marker='*', s=100, color='blue', label="Cluster 1 Center")

plt.scatter(zc_shape[mod_km_3.labels_ == 1].iloc[:,5], zc_shape[mod_km_3.labels_ == 1].iloc[:,24], \
           color='red', alpha=0.3, label="Cluster 2")
plt.scatter(centers_3[1][0], centers_3[1][-1], marker='*', s=100, color='red', label="Cluster 2 Center")

plt.scatter(zc_shape[mod_km_3.labels_ == 2].iloc[:,5], zc_shape[mod_km_3.labels_ == 2].iloc[:,24], \
           color='green', alpha=0.3, label="Cluster 3")
plt.scatter(centers_3[2][0], centers_3[2][-1], marker='*', s=100, color='green', label="Cluster 3 Center")

plt.xlabel("EST94")
plt.ylabel("EST14")
plt.title("KMeans Cluster: The Number Of ESTABLISHMENTS")
plt.legend(fontsize=10, loc='best')

# %%
#KMeans cluster
kmeans_cluster = KMeans(3).fit(zc_shape.iloc[:, range(5,26)])
centers = kmeans_cluster.cluster_centers_
zc_shape['km_labels'] = kmeans_cluster.labels_

# %%
#Plotting KMeans cluster spatially
f, ax = plt.subplots(figsize=(10,10))
zc_shape.plot(cmap='jet', column='km_labels', ax=ax, categorical=True, k=3)
ax.set_title("KMeans, k=3", fontsize=25)
ax.axes.get_xaxis().set_visible(False)
ax.axes.get_yaxis().set_visible(False)

# %%
mod_km_4 = KMeans(n_clusters=4, init='k-means++', n_init=10, max_iter=300, tol=0.0001, 
                verbose=0, random_state=None).fit(X)

# %%
centers_4 = mod_km_4.cluster_centers_

# %%
plt.figure(figsize=(8,8))
plt.scatter(zc_shape[mod_km_4.labels_ == 0].iloc[:,5], zc_shape[mod_km_4.labels_ == 0].iloc[:,24], \
           color='lightblue', alpha=0.3, label="Cluster 1")
plt.scatter(centers_4[0][0], centers_4[0][-1], marker='*', s=100, color='blue', label="Cluster 1 Center")

plt.scatter(zc_shape[mod_km_4.labels_ == 1].iloc[:,5], zc_shape[mod_km_4.labels_ == 1].iloc[:,24], \
           color='red', alpha=0.3, label="Cluster 2")
plt.scatter(centers_4[1][0], centers_4[1][-1], marker='*', s=100, color='red', label="Cluster 2 Center")

plt.scatter(zc_shape[mod_km_4.labels_ == 2].iloc[:,5], zc_shape[mod_km_4.labels_ == 2].iloc[:,24], \
           color='green', alpha=0.3, label="Cluster 3")
plt.scatter(centers_4[2][0], centers_4[2][-1], marker='*', s=100, color='green', label="Cluster 3 Center")

plt.scatter(zc_shape[mod_km_4.labels_ == 3].iloc[:,5], zc_shape[mod_km_4.labels_ == 3].iloc[:,24], \
           color='purple', alpha=0.3, label="Cluster 4")
plt.scatter(centers_4[3][0], centers_4[3][-1], marker='*', s=100, color='purple', label="Cluster 4 Center")

plt.xlabel("EST94")
plt.ylabel("EST14")
plt.title("KMeans Cluster: The Number Of ESTABLISHMENTS")
plt.legend(fontsize=10, loc='best')

# %%
#KMeans cluster
kmeans_cluster = KMeans(4).fit(zc_shape.iloc[:, range(5,26)])
centers = kmeans_cluster.cluster_centers_
zc_shape['km_labels'] = kmeans_cluster.labels_

# %%
#Plotting KMeans cluster spatially
f, ax = plt.subplots(figsize=(10,10))
zc_shape.plot(cmap='jet', column='km_labels', ax=ax, categorical=True, k=4)
ax.set_title("KMeans, k=4", fontsize=25)
ax.axes.get_xaxis().set_visible(False)
ax.axes.get_yaxis().set_visible(False)

# %%
Z = linkage(zc_shape.iloc[:,range(5,26)], 'ward')

# %%
plt.figure(figsize=(30,10))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('sample index')
plt.ylabel('distance')
dendrogram(
    Z,
    leaf_rotation=90.,  # rotates the x axis labels
    leaf_font_size=8.,  # font size for the x axis labels
)
plt.show()

# %%
HC_label = fcluster(Z, 4, criterion='maxclust')

# %%
zc_shape_2 = zc_shape.copy()
zc_shape_2['HC'] = HC_label
zc_shape_2['HC_'] = zc_shape_2.HC.replace([1,4],[4,1])

# %%
f, ax = plt.subplots(figsize=(10,10))
zc_shape_2.plot(cmap='hot_r', column='HC_', ax=ax, categorical=True, k=4)
ax.set_title("Hierarchical Clustering, k=4", fontsize=20)

# %%
#@Review: Incomplete
#6. Compare the results of the 2 algorithms
#7. attempt an interpretation.
